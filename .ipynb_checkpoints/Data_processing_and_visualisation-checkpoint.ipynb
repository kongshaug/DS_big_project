# %% [markdown]
# ### Stage 2: Business Data Storytelling
#
# In this notebook we load two stocks and performs a RSI and Moving Average analysis on them.
# Then we explore the engineered data in order to see if the new generated parameters, can widen our understandig of the data. We will do this by plotting the engineered data in a graph, and use it for analysing when to buy and sell the stocks. If the outcome of these analysis is not useful, it indicates that we should use more complex methods for prediction or combine these analysis with other types of data engineering for use in AI models.

# %%
import talib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from os import listdir

# %% [markdown]
# 1) First we load in the stock information and extract the open, high, low and closing price.
#
# 2) Then we clean the data by removing nan values
#
# 3) Afterwards we plot the graph to get a overview of the price evolvment.

# %%
path = r"./data/stocks/"
files = listdir(path)# many crypto 

for indx, file in enumerate(files[1:2]):
    print("nr. "+str(indx) +"/"+ str(len(files[1:2])))
    indx = 2
    dataset = pd.DataFrame()
    dataset = pd.read_csv(path + file)
    
    if len(dataset) < 800 and indx != 0:
        print("Dataset smaller then 800 skipping ...")
        continue
        
    dataset["Open"] = dataset["Open"].astype(float)
    dataset["High"] = dataset["High"].astype(float)
    dataset["Low"] = dataset["Low"].astype(float)
    dataset["Close"] = dataset["Close"].astype(float)
    dataset = dataset.reset_index()
    dataset = dataset.dropna()
    
    plt.style.use('fivethirtyeight')
    plt.figure(figsize=(20, 10))
    plt.xlabel("")
    plt.plot(dataset["Close"],color='g', label='close price')
    plt.show()
# Out:
# nr. 0/1

# %%
dataset['RSI'] = talib.RSI(dataset['Close'].values, timeperiod=20)
dataset['30day MA'] = dataset['Close'].shift(1).rolling(window=30).mean()
dataset['140day MA'] = dataset['Close'].shift(1).rolling(window=140).mean()
dataset.dropna(inplace=True)

# %%
dataset_sample = dataset[8000:8500]
plt.style.use('fivethirtyeight')
plt.figure(figsize=(20, 10))
plt.plot(dataset_sample["RSI"],color='purple', label='RSI')
plt.plot(dataset_sample["Close"],color='black', label='close price')
plt.plot(dataset_sample["140day MA"],color='b', label='140day MA')

plt.legend()
plt.show()

# %%
#moving average with RSI
# dataset["buy"] = np.where(((dataset["RSI"]< 40 )),1,0) # & (dataset["140day MA"]<dataset["Close"])
# dataset["sell"] = np.where(((dataset["RSI"]> 70 ) | (dataset["140day MA"]>dataset["Close"])),1,0) 

#double moving average
dataset["buy"] = np.where((dataset["140day MA"]<dataset["Close"]) & (dataset["30day MA"]<dataset["Close"] ),1,0)
dataset["sell"] = np.where((dataset["140day MA"]>dataset["Close"]) | (dataset["30day MA"]>dataset["Close"] ),1,0)

# %%
dataset["buy"] = np.where((dataset["buy"] == 1) &
                                  (dataset["buy"].shift(1) == 0), 1, 0)

dataset["buy_spot"] = np.where(
  (dataset["buy"] == 1), dataset["Close"], 0)

dataset["sell"] = np.where((dataset['sell'] == 1) &
                                (dataset['sell'].shift(1) == 0), 1, 0)

dataset["sell_spot"] = np.where(
  (dataset["sell"] == 1), dataset["Close"], 0)

# %%
dataset_sample = dataset[400:600]

# %%
plt.figure(figsize=(20, 10))
plt.plot(dataset_sample["Close"],color='black', label='close price')
# plt.plot(dataset_sample["RSI"],color='purple', label='30day MA')
plt.plot(dataset_sample["140day MA"],color='g', label='140day MA')
plt.scatter(dataset_sample.index,dataset_sample["buy_spot"],color='b', label='buy', marker="x",s=200)
plt.scatter(dataset_sample.index,dataset_sample["sell_spot"],color='r', label='sell', marker="x",s=200)
plt.legend()
plt.show()

# %%
dataset['Tomorrows Returns'] = 0.
dataset['Tomorrows Returns'] = dataset['Close'].shift(-1) - dataset['Close']

# %%
own = False
own_days = []
accumulated_market_return = 0
accumulated_stradegy_return = 0

for indx, row in dataset.iterrows():
    if row["buy_spot"] != 0:
        own = True
    if row["sell_spot"] != 0:
        own = False
    own_days.append(own)   
      
dataset["own"] = own_days

# %%
dataset['Strategy Returns'] = 0.
dataset['Strategy Returns'] = np.where(
  dataset['own'] == True, dataset['Tomorrows Returns'], 0)
dataset['Cumulative Market Returns'] = np.cumsum(
  dataset['Tomorrows Returns'])
dataset['Cumulative Strategy Returns'] = np.cumsum(
  dataset['Strategy Returns'])
dataset["buy"] = np.where((dataset['own'] == True) &
                              (dataset['own'].shift(1) == False), 1, 0)

# %%
dataset
# Out:
#        index        Date     Open     High      Low    Close   Volume  \
# 140      140  1970-07-22   1.5868   1.6079   1.5868   1.5868    51727
# 141      141  1970-07-23   1.5868   1.6079   1.5655   1.6079   310356
# 142      142  1970-07-24   1.6079   1.6079   1.5868   1.5868    45979
# 143      143  1970-07-27   1.5868   1.5868   1.5655   1.5868    67818
# 144      144  1970-07-28   1.5868   1.5868   1.5868   1.5868    63221
# ...      ...         ...      ...      ...      ...      ...      ...
# 12069  12069  2017-11-06  47.2000  47.6800  46.5300  47.2900  1725638
# 12070  12070  2017-11-07  47.1100  47.2042  46.5400  46.9700  2168351
# 12071  12071  2017-11-08  46.7300  46.7700  45.3700  45.8900  3347930
# 12072  12072  2017-11-09  44.7100  44.7100  43.1100  43.3300  7671810
# 12073  12073  2017-11-10  42.9300  44.4600  42.7500  43.0100  4463839
#
#        OpenInt        RSI   30day MA  140day MA  buy  sell  buy_spot  \
# 140          0  40.009619   1.647960   2.022735    0     0       0.0
# 141          0  42.558061   1.643077   2.017661    0     0       0.0
# 142          0  40.736462   1.639583   2.012889    0     0       0.0
# 143          0  40.736462   1.638197   2.008265    0     0       0.0
# 144          0  40.736462   1.636127   2.003641    0     0       0.0
# ...        ...        ...        ...        ...  ...   ...       ...
# 12069        0  53.650268  47.461667  38.538286    0     0       0.0
# 12070        0  52.109366  47.528333  38.652500    0     0       0.0
# 12071        0  47.284634  47.602667  38.759143    0     0       0.0
# 12072        0  38.410931  47.630000  38.860500    0     0       0.0
# 12073        0  37.485311  47.538333  38.932071    0     0       0.0
#
#        sell_spot  Tomorrows Returns    own  Strategy Returns  \
# 140          0.0             0.0211  False               0.0
# 141          0.0            -0.0211  False               0.0
# 142          0.0             0.0000  False               0.0
# 143          0.0             0.0000  False               0.0
# 144          0.0             0.0211  False               0.0
# ...          ...                ...    ...               ...
# 12069        0.0            -0.3200  False               0.0
# 12070        0.0            -1.0800  False               0.0
# 12071        0.0            -2.5600  False               0.0
# 12072        0.0            -0.3200  False               0.0
# 12073        0.0                NaN  False               0.0
#
#        Cumulative Market Returns  Cumulative Strategy Returns
# 140                       0.0211                       0.0000
# 141                       0.0000                       0.0000
# 142                       0.0000                       0.0000
# 143                       0.0000                       0.0000
# 144                       0.0211                       0.0000
# ...                          ...                          ...
# 12069                    45.3832                      19.4377
# 12070                    44.3032                      19.4377
# 12071                    41.7432                      19.4377
# 12072                    41.4232                      19.4377
# 12073                        NaN                      19.4377
#
# [11934 rows x 20 columns]

# %%
dataset_sample = dataset
dataset_sample = dataset[200:1000]
plt.figure(figsize=(20, 10))
plt.plot(dataset_sample["Cumulative Market Returns"],color='black', label='market return')
plt.plot(dataset_sample["Cumulative Strategy Returns"],color='b', label='Strategy return')
# plt.scatter(dataset_sample.index,dataset_sample["buy_spot"],color='b', label='30day MA', marker="x",s=80)
# plt.scatter(dataset_sample.index,dataset_sample["sell_spot"],color='r', label='30day MA', marker="x",s=80)
plt.legend()
plt.show()

# %%
print("the total accumilated market return is: ", dataset["Cumulative Market Returns"].iloc[-2])
print("the total accumilated Strategy return is: ", dataset["Cumulative Strategy Returns"].iloc[-2])
# Out:
# the total accumilated market return is:  41.4232
# the total accumilated Strategy return is:  -15.68699999999997

# %%
dataset.to_csv(r"C:\Users\benja\OneDrive\Skrivebord\skole\DataScience\bigproject\DS_big_project\story\one_msi/rsi_1.csv")

# %%
dataset
# Out:
#        index        Date     Open     High      Low    Close   Volume  \
# 140      140  1970-07-22   1.5868   1.6079   1.5868   1.5868    51727
# 141      141  1970-07-23   1.5868   1.6079   1.5655   1.6079   310356
# 142      142  1970-07-24   1.6079   1.6079   1.5868   1.5868    45979
# 143      143  1970-07-27   1.5868   1.5868   1.5655   1.5868    67818
# 144      144  1970-07-28   1.5868   1.5868   1.5868   1.5868    63221
# ...      ...         ...      ...      ...      ...      ...      ...
# 12069  12069  2017-11-06  47.2000  47.6800  46.5300  47.2900  1725638
# 12070  12070  2017-11-07  47.1100  47.2042  46.5400  46.9700  2168351
# 12071  12071  2017-11-08  46.7300  46.7700  45.3700  45.8900  3347930
# 12072  12072  2017-11-09  44.7100  44.7100  43.1100  43.3300  7671810
# 12073  12073  2017-11-10  42.9300  44.4600  42.7500  43.0100  4463839
#
#        OpenInt        RSI   30day MA  140day MA  buy  sell  buy_spot  \
# 140          0  40.009619   1.647960   2.022735    0     0      0.00
# 141          0  42.558061   1.643077   2.017661    0     0      0.00
# 142          0  40.736462   1.639583   2.012889    0     0      0.00
# 143          0  40.736462   1.638197   2.008265    0     0      0.00
# 144          0  40.736462   1.636127   2.003641    0     0      0.00
# ...        ...        ...        ...        ...  ...   ...       ...
# 12069        0  53.650268  47.461667  38.538286    0     0      0.00
# 12070        0  52.109366  47.528333  38.652500    0     0      0.00
# 12071        0  47.284634  47.602667  38.759143    0     0      0.00
# 12072        0  38.410931  47.630000  38.860500    1     0     43.33
# 12073        0  37.485311  47.538333  38.932071    0     0      0.00
#
#        sell_spot  Tomorrows Returns    own  Strategy Returns  \
# 140          0.0             0.0211  False              0.00
# 141          0.0            -0.0211  False              0.00
# 142          0.0             0.0000  False              0.00
# 143          0.0             0.0000  False              0.00
# 144          0.0             0.0211  False              0.00
# ...          ...                ...    ...               ...
# 12069        0.0            -0.3200  False              0.00
# 12070        0.0            -1.0800  False              0.00
# 12071        0.0            -2.5600  False              0.00
# 12072        0.0            -0.3200   True             -0.32
# 12073        0.0                NaN   True               NaN
#
#        Cumulative Market Returns  Cumulative Strategy Returns
# 140                       0.0211                        0.000
# 141                       0.0000                        0.000
# 142                       0.0000                        0.000
# 143                       0.0000                        0.000
# 144                       0.0211                        0.000
# ...                          ...                          ...
# 12069                    45.3832                      -15.367
# 12070                    44.3032                      -15.367
# 12071                    41.7432                      -15.367
# 12072                    41.4232                      -15.687
# 12073                        NaN                          NaN
#
# [11934 rows x 20 columns]

# %%
pip install jupyter-dash
# Out:
# Requirement already satisfied: jupyter-dash in c:\users\benja\anaconda3\envs\bert\lib\site-packages (0.4.0)Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.0.1; however, version 21.1.1 is available.
# You should consider upgrading via the 'C:\Users\benja\Anaconda3\envs\bert\python.exe -m pip install --upgrade pip' command.
# Requirement already satisfied: ansi2html in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-dash) (1.6.0)
# Requirement already satisfied: ipython in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-dash) (7.19.0)
# Requirement already satisfied: flask in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-dash) (1.1.2)
# Requirement already satisfied: retrying in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-dash) (1.3.3)
# Requirement already satisfied: dash in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-dash) (1.20.0)
# Requirement already satisfied: requests in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-dash) (2.24.0)
# Requirement already satisfied: ipykernel in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-dash) (5.3.4)
# Requirement already satisfied: flask-compress in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from dash->jupyter-dash) (1.9.0)
# Requirement already satisfied: dash-table==4.11.3 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from dash->jupyter-dash) (4.11.3)
# Requirement already satisfied: dash-renderer==1.9.1 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from dash->jupyter-dash) (1.9.1)
# Requirement already satisfied: dash-core-components==1.16.0 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from dash->jupyter-dash) (1.16.0)
# Requirement already satisfied: future in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from dash->jupyter-dash) (0.18.2)
# Requirement already satisfied: plotly in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from dash->jupyter-dash) (4.14.3)
# Requirement already satisfied: dash-html-components==1.1.3 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from dash->jupyter-dash) (1.1.3)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from flask->jupyter-dash) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from flask->jupyter-dash) (2.11.2)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from flask->jupyter-dash) (0.16.1)
# Requirement already satisfied: click>=5.1 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from flask->jupyter-dash) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from Jinja2>=2.10.1->flask->jupyter-dash) (1.1.1)
# Requirement already satisfied: brotli in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from flask-compress->dash->jupyter-dash) (1.0.9)
# Requirement already satisfied: jupyter-client in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipykernel->jupyter-dash) (6.1.7)
# Requirement already satisfied: tornado>=4.2 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipykernel->jupyter-dash) (6.0.4)
# Requirement already satisfied: traitlets>=4.1.0 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipykernel->jupyter-dash) (5.0.5)
# Requirement already satisfied: setuptools>=18.5 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (54.0.0)
# Requirement already satisfied: pygments in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (2.7.2)
# Requirement already satisfied: decorator in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (4.4.2)
# Requirement already satisfied: backcall in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (0.2.0)
# Requirement already satisfied: pickleshare in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (0.7.5)
# Requirement already satisfied: colorama in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (0.4.4)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (3.0.8)
# Requirement already satisfied: jedi>=0.10 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from ipython->jupyter-dash) (0.17.2)
# Requirement already satisfied: parso<0.8.0,>=0.7.0 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jedi>=0.10->ipython->jupyter-dash) (0.7.0)
# Requirement already satisfied: wcwidth in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->jupyter-dash) (0.2.5)
# Requirement already satisfied: ipython-genutils in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from traitlets>=4.1.0->ipykernel->jupyter-dash) (0.2.0)
# Requirement already satisfied: pyzmq>=13 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (19.0.2)
# Requirement already satisfied: jupyter-core>=4.6.0 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (4.6.3)
# Requirement already satisfied: python-dateutil>=2.1 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-client->ipykernel->jupyter-dash) (2.8.1)
# Requirement already satisfied: pywin32>=1.0 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from jupyter-core>=4.6.0->jupyter-client->ipykernel->jupyter-dash) (227)
# Requirement already satisfied: six>=1.5 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from python-dateutil>=2.1->jupyter-client->ipykernel->jupyter-dash) (1.15.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from requests->jupyter-dash) (2020.12.5)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from requests->jupyter-dash) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from requests->jupyter-dash) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\users\benja\anaconda3\envs\bert\lib\site-packages (from requests->jupyter-dash) (1.25.11)

# %%
import glob
files = glob.glob(r"C:\Users\benja\OneDrive\Skrivebord\skole\DataScience\bigproject\DS_big_project\data\Stocks/*.txt")

files = [file.split("\\")[-1] for file in files]

# %%
files = ['a.us.txt',
 'burl.us.txt',
 'buse.us.txt',
 'buz.us.txt',
 'bv.us.txt',
 'bval.us.txt',
 'bvn.us.txt',
 'bvsn.us.txt',
 'bvx.us.txt',
 'bvxv.us.txt',
 'bvxvw.us.txt',
 'bw.us.txt',
 'bwa.us.txt',
 'bwen.us.txt',
 'bwfg.us.txt',
 'bwg.us.txt',
 'bwina.us.txt',
 'bwinb.us.txt',
 'bwl-a.us.txt',
 'bwld.us.txt',
 'bwp.us.txt',
 'bwxt.us.txt',
 'bx.us.txt',
 'bxc.us.txt',
 'bxe.us.txt',
 'bxg.us.txt',
 'bxmt.us.txt',]

# %%
import plotly.express as px
from jupyter_dash import JupyterDash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output

# Load Data
df = px.data.tips()

# Load file names


# Build App
app = JupyterDash(__name__)
app.layout = html.Div([
    html.H1("DashBoard"),
        html.Label('Checkboxes'),
    dcc.Checklist(
        options=[
            {'label': 'moving average Strategy', 'value': 'moving'},
            {'label': 'moving average with MSI Strategy', 'value': 'msi'},
        ],
        value=['moving', 'msi']
    ),
    dcc.Graph(id='graph'),
    html.Label([
        "Stock",
        dcc.Dropdown(
            id='stock-dropdown', clearable=False,
            value='aby.us', options=[
                {'label': c, 'value': c}
                for c in files
            ])
    ]),
    
])
# Define callback to update graph
@app.callback(
    Output('graph', 'figure'),
    [Input("stock-dropdown", "value")]
)
def update_figure(colorscale):
    
    return px.line(
        dataset,  y=["Close","140day MA", "Cumulative Strategy Returns"], 
        render_mode="webgl", title="Closing price each day"
    )
# Run app and display result inline in the notebook
app.run_server(mode='inline')
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
dataset
# Out:
#        Close    High     Low    Open        RSI   140day MA  buy  sell  \
# 420   695.07  703.06  695.00  702.22  50.669622  845.545429    0     0
# 421   682.30  695.01  675.00  690.00  48.887250  844.074429    0     0
# 422   682.32  682.32  682.01  682.01  48.890214  842.398071    0     0
# 423   695.00  705.00  675.00  675.00  50.794450  841.757500    0     0
# 424   703.00  705.44  694.75  694.75  51.982576  841.007500    0     0
# ...      ...     ...     ...     ...        ...         ...  ...   ...
# 1206   88.00   88.25   85.50   85.50  50.831022   84.980994    1     0
# 1207   80.40   80.40   80.40   80.40  43.188832   85.147066    0     1
# 1208   81.00   81.00   80.10   80.60  43.889874   85.242780    0     0
# 1209   84.05   84.05   84.05   84.05  47.365298   85.328494    0     0
# 1210   80.10   84.20   80.10   84.20  43.677259   85.431709    0     0
#
#       buy_spot  sell_spot  Tomorrows Returns    own  Strategy Returns  \
# 420        0.0        0.0                NaN  False             0.000
# 421        0.0        0.0            -12.770  False             0.000
# 422        0.0        0.0              0.020  False             0.000
# 423        0.0        0.0             12.680  False             0.000
# 424        0.0        0.0              8.000  False             0.000
# ...        ...        ...                ...    ...               ...
# 1206      88.0        0.0              3.625   True             3.625
# 1207       0.0       80.4             -7.600  False             0.000
# 1208       0.0        0.0              0.600  False             0.000
# 1209       0.0        0.0              3.050  False             0.000
# 1210       0.0        0.0             -3.950  False             0.000
#
#       Cumulative Market Returns  Cumulative Strategy Returns    30day MA
# 420                         NaN                        0.000  639.675667
# 421                      -12.77                        0.000  642.410667
# 422                      -12.75                        0.000  645.820667
# 423                       -0.07                        0.000  650.290000
# 424                        7.93                        0.000  654.357333
# ...                         ...                          ...         ...
# 1206                    -607.07                      130.225   87.740420
# 1207                    -614.67                      130.225   87.028753
# 1208                    -614.07                      130.225   86.460420
# 1209                    -611.02                      130.225   85.777087
# 1210                    -614.97                      130.225   85.312087
#
# [791 rows x 16 columns]
